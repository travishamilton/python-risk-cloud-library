# %% [markdown]
# # Python Riskcloud Library
#
# This notebook demos the riskcloudpy library. The library interfaces with LogicGate's API providing the user access to the endpoints. The library is only compatiable with our QA environment and requires a username and password. First, the relevant libraries are installed. Note the `riskcloudpy` is the first library to be installed.

# %%
import sys
# !{sys.executable} -m pip install riskcloudpy
# !{sys.executable} -m pip install pandas
# !{sys.executable} -m pip install matplotlib

# %% [markdown]
# Next, python requires us to import the libraries we want to use in our script. In this case, we will import all of the libraries we installed previously. In this case, we are importing the `Session` class from the `riskcloudpy` library. The remaining library are related to data science.

# %%
from riskcloudpy import Session
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# The url of the LG's QA enviornment is provided along with a username and password. These are passed to our `Session` class. The class will establish a connection to our QA API behind the scenes. Once the connection is established, we can make specific requests. Here, we make a request to the account and applications endpoint. They will return all account and application information respecitvaly.

# %%
base_url = ''
username = ""
password = ""

####################################################
############----Send Requests to API----############
####################################################

session = Session(username,password,base_url)
assert(session.authentication_status==200)

r = session.account_endpoint()
assert(r.status_code==200)

r = session.applications_endpoint()
assert(r.status_code==200)

# %% [markdown]
# With the output collected in `r` it can now be converted to a json format and placed within a pandas dataframe. The dataframe is a table of data and acts as the basic building block for data science.

# %%
####################################################
####----Convert Json Response into Dataframe----####
####################################################

df = pd.DataFrame(r.json())
df.head(5) #Print the first 5 rows of the dataframe. It will appear as a table.
# Out:
#          id  active        created       updated               name    color  \
# 0  J2En8ZMb    True  1539952086237  1.541103e+12          TR Tester  #00facc
# 1  POHBBCp8    True  1539917810874  1.539918e+12  Table Report Town  #00a3de
# 2  hGGJzT1z    True  1540229243265  1.540319e+12       Elizabeth QA  #fa0096
# 3  pEyPfJRE    True  1540218415374  1.544743e+12        Attachments  #fdae60
# 4  AyuF1oAr    True  1540236339092  1.554739e+12   TR Tester (Copy)  #00facc
#
#                            icon  type  permissionsEnabled  imported  copied  \
# 0                  fas__fa-gift  None               False     False   False
# 1                 fas__fa-cubes  None               False     False   False
# 2             fas__fa-heartbeat  None               False     False   False
# 3  fas__fa-exclamation-triangle  None               False     False   False
# 4                  fas__fa-gift  None               False     False   False
#
#     live
# 0  False
# 1  False
# 2  False
# ...

# %% [markdown]
# This section is more technical is often refered to as "data cleaning". Within the created and updated column, the time is recored in Unix millisecond time. This standard defines time relative to milliseconds since January 1st 1970 UTC. Python and pandas provide a number of built in functions to convert Unix time to central standard time.

# %%
####################################################
####----Convert Time Series Data to CST Time----####
####################################################

#created and updated are in Unix ms time. Convert to date time
df['created'] = pd.to_datetime(df['created'], unit='ms')
df['updated'] = pd.to_datetime(df['updated'], unit='ms')

#set time zone to UTC and convert to US/Central
df.created = df.created.dt.tz_localize('UTC').dt.tz_convert('US/Central')
df.updated = df.updated.dt.tz_localize('UTC').dt.tz_convert('US/Central')
df['active']= (df.updated-df.created).dt.days

today = pd.to_datetime('today').normalize()
today = today.tz_localize('US/Central')

df['best active']= (today-df.created).dt.days

cutoff = pd.to_datetime('2019-01-01')
cutoff = cutoff.tz_localize('US/Central')

# %% [markdown]
# Now that the data has been cleaned, it's time to plot our data. First, will look at when applications are created using a bar graph. Note that this is effectively a histogram where the x-axis tell us the hour of creation (often referred to as bins) and the y-axis is the number of applictionas with that hour of creation (number of items per bin).

# %%
####################################################
###############----Plot Dataframe----###############
####################################################
##############----Hour of Creation----##############

fig, axs = plt.subplots(figsize=(12,4))
df.groupby(df['created'].dt.hour).size().plot(kind='bar',rot=0,ax=axs)
plt.xlabel("Hour of the Day Application is Created")
plt.ylabel("Number of Applications")
plt.title("Number of Applications vs. Hour of the Day of Creation (CST)")
# Out:
# Text(0.5, 1.0, 'Number of Applications vs. Hour of the Day of Creation (CST)')

# %%
####################################################
###############----Plot Dataframe----###############
####################################################
##############----Most Active App----###############

fig, axs = plt.subplots(figsize=(12,4))
df[df.active>0.0].plot(x='created',y='active',kind='scatter',ax=axs,logy=True, c='color')
df[df.active>0.0].plot(x='created',y='best active',kind='line',ax=axs,logy=True)
plt.title("Application Active Time (Days) vs. Creation Date with App Color")
plt.ylabel("active (days)")
# Out:
# Text(0, 0.5, 'active (days)')

# %%
####################################################
#############----Tabulate Dataframe ---#############
####################################################
##############----Most Active App----###############

print(tabulate(df.sort_values(by=['active'],ascending=[False])[['name','active','created','color','id']].head(10),headers='keys',tablefmt='psql'))
# Out:
# +-----+-----------------------------+----------+---------------+---------+----------+
# |     | name                        | active   |       created | color   | id       |
# |-----+-----------------------------+----------+---------------+---------+----------|
# |   0 | TR Tester                   | True     | 1539952086237 | #00facc | J2En8ZMb |
# | 769 | Kras Dev Application (Copy) | True     | 1591798036051 | #ff6a00 | jN2Hek1k |
# | 675 | gmqa (Copy)                 | True     | 1587580729792 | #3126a6 | AoWAttYG |
# | 676 | ! 75 app                    | True     | 1619598003809 | #2d3940 | cPTijYm6 |
# | 677 | [bb] calc label test        | True     | 1628627697247 | #00a3de | V9dvZdSJ |
# | 678 | ! Application 74            | True     | 1613466224012 | #49b800 | x93znkVM |
# | 679 | ! appT7-job_reset_record    | True     | 1613486186338 | #b82e73 | TVmjAfph |
# | 680 | CalcFieldTest               | True     | 1619801927988 | #00a3de | GAGJperM |
# ...

# %%
####################################################
###############----Plot Dataframe----###############
####################################################
################----Unused Apps----#################

fig, axs = plt.subplots(figsize=(12,4))
df.plot(x='created',y='updated',kind='scatter',ax=axs,c='color')
plt.title("Application Update Date vs. Creation Date with App Color")
# Out:
# Text(0.5, 1.0, 'Application Update Date vs. Creation Date with App Color')

# %%
####################################################
#############----Tabulate Dataframe ---#############
####################################################
################----Unused Apps----#################

print(tabulate(df[df['updated']<cutoff].sort_values(by='updated',ascending=True)[['name','updated','color','id']],headers='keys',tablefmt='psql'))
# Out:
# +----+------------------------------+-------------------------------------+---------+----------+
# |    | name                         | updated                             | color   | id       |
# |----+------------------------------+-------------------------------------+---------+----------|
# |  1 | Table Report Town            | 2018-10-18 21:57:03.155000064-05:00 | #00a3de | POHBBCp8 |
# |  5 | Test                         | 2018-10-22 20:30:25.187000064-05:00 | #00a3de | ebNCQoQ1 |
# |  2 | Elizabeth QA                 | 2018-10-23 13:22:46.036000-05:00    | #fa0096 | hGGJzT1z |
# | 10 | TR Tester (Copy)             | 2018-11-01 15:17:19.003000064-05:00 | #00facc | 1yLVnuUh |
# |  0 | TR Tester                    | 2018-11-01 15:17:20.228000-05:00    | #00facc | J2En8ZMb |
# | 11 | Szuyin                       | 2018-11-20 09:00:06.296000-06:00    | #5b12b8 | 14beb88h |
# | 13 | Conditional Copy Test        | 2018-12-03 09:07:47.928000-06:00    | #00a3de | QeiqcCWq |
# ...
